# %% [markdown]
# ## Введение\n\nЦель проекта: изучить данные и сделать выводы.

# %%
import pandas as pd\ndf = pd.DataFrame({'a': [1, 1, None], 'b': [1, 2, 3]})\ndf.head()

# %%
df.duplicated().sum()

# %% [markdown]
# ## Вывод\n\nМожно сделать вывод, что данные загружены корректно.
